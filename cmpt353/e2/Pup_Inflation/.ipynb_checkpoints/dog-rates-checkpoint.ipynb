# %%
import numpy as np
import pandas as pd

# %%
#pd.read_csv(filename12, sep=' ', header=None, index_col=1,
 #       names=['lang', 'page', 'views', 'bytes'])

# %%
#totals = pd.read_csv('dog_rates_tweets.csv').set_index(keys=['name'])
dog_rates_tweets = pd.read_csv('dog_rates_tweets.csv')
dog_rates_tweets
# Out:
#                        id           created_at  \
# 0      994677639364403200  2018-05-10 20:36:44
# 1      994364904978239488  2018-05-09 23:54:02
# 2      994363623421153280  2018-05-09 23:48:56
# 3      994336722875047936  2018-05-09 22:02:03
# 4      994024065982717952  2018-05-09 01:19:40
# 5      993944355051376640  2018-05-08 20:02:55
# 6      993889355365257217  2018-05-08 16:24:22
# 7      993889039714578432  2018-05-08 16:23:07
# 8      993629544463642624  2018-05-07 23:11:58
# 9      993551676568195072  2018-05-07 18:02:33
# 10     993551435202793473  2018-05-07 18:01:36
# 11     993550370105430016  2018-05-07 17:57:22
# 12     993550075723964417  2018-05-07 17:56:11
# 13     993549188377055232  2018-05-07 17:52:40
# 14     993547462743920640  2018-05-07 17:45:48
# 15     993545616734195718  2018-05-07 17:38:28
# 16     993479993828298752  2018-05-07 13:17:43
# 17     993289347507027968  2018-05-07 00:40:09
# 18     992835484916346880  2018-05-05 18:36:40
# ...

# %%
import re
answer = re.search("\d/10", "find me 5/10")
answer
# Out:
# <re.Match object; span=(8, 12), match='5/10'>

# %%
only_ratings =dog_rates_tweets[dog_rates_tweets['text'].str.contains("\d/10")]
only_ratings
# Out:
#                        id           created_at  \
# 2      994363623421153280  2018-05-09 23:48:56
# 7      993889039714578432  2018-05-08 16:23:07
# 8      993629544463642624  2018-05-07 23:11:58
# 24     992198572664860672  2018-05-04 00:25:48
# 30     991744041351090177  2018-05-02 18:19:39
# 35     991399795892916224  2018-05-01 19:31:45
# 41     990987750601093120  2018-04-30 16:14:26
# 50     989657223084244992  2018-04-27 00:07:23
# 55     989300750152069120  2018-04-26 00:30:53
# 59     989176681243070464  2018-04-25 16:17:53
# 60     988932682615853057  2018-04-25 00:08:19
# 62     988573045076963328  2018-04-24 00:19:15
# 65     988455306224128006  2018-04-23 16:31:24
# 66     988208849340510209  2018-04-23 00:12:04
# 75     987398687562371072  2018-04-20 18:32:46
# 77     986762231290490881  2018-04-19 00:23:43
# 79     986639920189108224  2018-04-18 16:17:42
# 80     986394000415485952  2018-04-18 00:00:30
# 83     985700162956865536  2018-04-16 02:03:26
# ...

# %%
only_ratings['ratings'] = only_ratings['text'].str.extract('(\d/10)', expand=False).str.strip()
only_ratings['ratings'] = only_ratings['text'].str.extract('(^\d)', expand=False).str.strip()
only_ratings
# Out:
# /home/sarbjot/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sarbjot/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                        id           created_at  \
# 2      994363623421153280  2018-05-09 23:48:56
# 7      993889039714578432  2018-05-08 16:23:07
# 8      993629544463642624  2018-05-07 23:11:58
# ...
